# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# %run algorithm1.ipynb
# %run algorithm2.ipynb
# %run generate_graph.ipynb

# %%
# Random graph
G = nx.erdos_renyi_graph(n = 15, p = 0.2, directed = False)
nx.draw_networkx(G, with_labels=True)
plt.show()

# %%
# This parameter was implemented for debugging
plot_solution = False

min_FVS_alg1 = minimal_fvs_alg1(G, plot_solution)[0]
min_FVS_alg2 = minimal_fvs_alg2(G, plot_solution)[0]
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-06-05
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 10 rows, 12 columns and 24 nonzeros
# Model fingerprint: 0x139f2555
# Model has 6 quadratic constraints
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#   QRHS range       [1e+00, 1e+00]
# Presolve removed 10 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# ...

# %%
len(min_FVS_alg1) == len(min_FVS_alg2)
# Out:
# True

# %%
# Graph generated with our algorithm
n = 30
k = 8
G = generating_graphs(n, k)[0]
nx.draw_networkx(G, with_labels=True)
plt.show()

# %%
min_FVS_alg1 = minimal_fvs_alg1(G, plot_solution)[0]
min_FVS_alg2 = minimal_fvs_alg2(G, plot_solution)[0]
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 13 rows, 12 columns and 26 nonzeros
# Model fingerprint: 0x88a9c4da
# Model has 4 quadratic constraints
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#   QRHS range       [1e+00, 1e+00]
# Presolve removed 13 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# ...

# %%
len(min_FVS_alg1) == len(min_FVS_alg2)
# Out:
# True

# %%
# Graph from the testing dataset of generated graphs

# Provide path to the folder Fixed-Parameter Tractable Algorithms for Feedback Vertex Set, Vladimir Minaev
root_path = 
folder_path = "Fixed-Parameter Tractable Algorithms for Feedback Vertex Set, Vladimir Minaev/Generated graphs/" 

# Choose a small number as the name of the file, so that the runtime is small
filename = "1.adjlist"

G = nx.read_multiline_adjlist(root_path + folder_path + filename, nodetype=int)

min_FVS_alg1 = minimal_fvs_alg1(G, plot_solution)[0]
min_FVS_alg2 = minimal_fvs_alg2(G, plot_solution)[0]
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 10 rows, 12 columns and 24 nonzeros
# Model fingerprint: 0x26a12915
# Model has 6 quadratic constraints
# Variable types: 0 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
#   QRHS range       [1e+00, 1e+00]
# Presolve removed 10 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# ...

# %%
len(min_FVS_alg1) == len(min_FVS_alg2)
# Out:
# True
